# %% [markdown]
# # Lab 08: Penguins EDA & Simple Modeling
#
# **ING3513 - Introduction to Artificial Intelligence and Machine Learning**
#
# A hands-on practice session to apply EDA and modeling skills from Lab 07 to the **Palmer Penguins** dataset.
#
# The Palmer Penguins dataset contains measurements for three penguin species (Adelie, Chinstrap, Gentoo) observed on islands in Antarctica. The typical machine learning task with this dataset is to **predict the species** based on physical features like bill length, bill depth, flipper length, and body mass.
#
# This lab is very open ended. The goal is simply to have a playground to explore how the tools actually work without many examples. You are encouraged to use AI to help understand. Recommended pattern:
#
# 1. Figure out what you want to do. E.g., plot a histogram.
# 2. Search or check previous labs for how to do that.
# 3. Try to implement it yourself.
# 4. If you are stuck, ask a co-student or a teacher.
# 5. Use AI if still stuck
# 6. Use AI to explain and understand is always encouraged. Try to always understand every single line of code.
#
# **Structure:**
#
# - **Part 1:** Exploratory Data Analysis — load, inspect, and understand the data
# - **Part 2:** Model Fitting — build a simple classifier to predict penguin species

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# These could be useful
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

SEED = 42
print("Libraries loaded!")

# %% [markdown]
# ---
#
# ## Part 1: Exploratory Data Analysis
#
# Load the penguins dataset and explore its structure.

# %%
# Load the data
df = sns.load_dataset("penguins")

print(f"Shape: {df.shape}")
df.head()

# %%
# Quick visualization: pair plot
sns.pairplot(df, hue="species")
plt.show()

# %%
# Continue exploring the data

# Develop hypothesis

# %% [markdown]
# ---
#
# ## Part 2: Feature Selection and Model Fitting
#
# Build a simple logistic regression model to predict penguin species from numeric features.

# %%
# Prepare the data: drop missing values, select numeric features
df_clean = df.dropna()

feature_cols = ["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]
X = df_clean[feature_cols]
y = df_clean["species"]

print(f"Samples: {len(X)}, Features: {len(feature_cols)}")

# %%
# Train/test split

## Consider using stratification during splitting (look it up)

# Select features

# Scale/Normalize

# Fit model

# Evaluate model
